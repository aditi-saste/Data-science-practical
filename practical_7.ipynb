# %% [markdown]
# <a href="https://colab.research.google.com/github/aditi-saste/Data-science-practical/blob/main/practical_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_excel("/content/primary dataset.xlsx")
data
# Out:
#    roll no     name class  pointer grade
# 0     6205    aditi     b      9.5    A+
# 1     6206   suhani     b      8.9    A+
# 2     6207  kalpana     b      7.8     B
# 3     6208  kalpesh     b      8.9    A+
# 4     6209    soham     b      6.7     B
# 5     6210    omkar     b      9.0    A+
# 6     6211   prerna     b      8.9     A
# 7     6212   sanika     b      6.7     C
# 8     6213    mansi     b      8.8     A

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("/content/radhe radhe.jpg")
plt.imshow(image)

# %% [markdown]
# summarizing data with statistics

# %%
import pandas as pd
df=pd.DataFrame({"sr.no": [1,1,3,4,5],"rollno":[6205,6205,6207,6208,6209],
                 "name":["Aditi","Aditi","perena","sanika","kalpana"],
                "class":["A","B","A","A","B"],"marks":[0,67,67,54,40]})
df
# Out:
#    sr.no  rollno     name class  marks
# 0      1    6205    Aditi     A      0
# 1      1    6205    Aditi     B     67
# 2      3    6207   perena     A     67
# 3      4    6208   sanika     A     54
# 4      5    6209  kalpana     B     40

# %%
df.isnull().sum()
# Out:
# sr.no     0
# rollno    0
# name      0
# class     0
# marks     0
# dtype: int64

# %%
df.describe()
# Out:
#           sr.no       rollno      marks
# count  5.000000     5.000000   5.000000
# mean   2.800000  6206.800000  63.600000
# std    1.788854     1.788854  18.501351
# min    1.000000  6205.000000  40.000000
# 25%    1.000000  6205.000000  54.000000
# 50%    3.000000  6207.000000  67.000000
# 75%    4.000000  6208.000000  67.000000
# max    5.000000  6209.000000  90.000000

# %%
df.value_counts()
# Out:
# sr.no  rollno  name     class  marks
# 1      6205    Aditi    A      90       1
#                         B      67       1
# 3      6207    perena   A      67       1
# 4      6208    sanika   A      54       1
# 5      6209    kalpana  B      40       1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sr.no   5 non-null      int64
#  1   rollno  5 non-null      int64
#  2   name    5 non-null      object
#  3   class   5 non-null      object
#  4   marks   5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 328.0+ bytes

# %%
df.describe(include="object")
# Out:
#          name class
# count       5     5
# unique      4     2
# top     Aditi     A
# freq        2     3

# %%
df.nunique()
# Out:
# sr.no     4
# rollno    4
# name      4
# class     2
# marks     4
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(['name']).sum()
# Out:
# 1

# %%
df.nunique()
# Out:
# sr.no     4
# rollno    4
# name      4
# class     2
# marks     4
# dtype: int64

# %%
df['name'].value_counts()
# Out:
# Aditi      2
# perena     1
# sanika     1
# kalpana    1
# Name: name, dtype: int64

# %%
df['class'].value_counts()
# Out:
# A    3
# B    2
# Name: class, dtype: int64

# %%
df['class'].nunique()
# Out:
# 2

# %%
df['marks'].mean()
# Out:
# 63.6

# %%
df.var()
# Out:
# <ipython-input-89-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# sr.no       3.2
# rollno      3.2
# marks     774.3
# dtype: float64

# %%
correlation=df.corr()
correlation
# Out:
# <ipython-input-92-edac34d0c35e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()
#            sr.no    rollno     marks
# sr.no   1.000000  1.000000  0.229021
# rollno  1.000000  1.000000  0.229021
# marks   0.229021  0.229021  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True,fmt='.2f',cmap='plasma')
# Out:
# <Axes: >
